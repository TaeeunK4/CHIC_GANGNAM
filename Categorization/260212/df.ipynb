# %%
import pandas as pd

# %%
df = pd.read_csv('03_CG_eBay_active_listing_data_filtered_with_brand.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4064 entries, 0 to 4063
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item number           4064 non-null   int64
#  1   origin_id             1053 non-null   float64
#  2   Title                 4064 non-null   object
#  3   eBay category 1 name  4064 non-null   object
#  4   raw_data              1053 non-null   object
#  5   brand                 1053 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 190.6+ KB
