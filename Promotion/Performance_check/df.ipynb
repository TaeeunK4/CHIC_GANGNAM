# %%
import pandas as pd

# %%
df = pd.read_csv('CPC_PROMOTION_260219_260222_Query_20260224.csv', skiprows=2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 25 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Start date                               347 non-null    object
#  1   End date                                 347 non-null    object
#  2   Campaign name                            347 non-null    object
#  3   Campaign ID                              347 non-null    int64
#  4   Campaign start date                      347 non-null    object
#  5   Campaign end date                        347 non-null    object
#  6   Targeting strategy                       347 non-null    object
#  7   Ad Group Name                            0 non-null      float64
#  8   Ad Group Id                              0 non-null      float64
#  9   Seller Keyword                           0 non-null      float64
# ...

# %%
df = df.dropna(axis=1, how='all')

# %%
df.sort_values(by='Impressions ', ascending=False)
# Out:
#        Start date      End date                Campaign name   Campaign ID  \
# 304  Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 217  Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 177  Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 31   Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 25   Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# ..            ...           ...                          ...           ...
# 342  Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 3    Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 344  Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 345  Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
# 2    Feb 18, 2026  Feb 24, 2026  CPC_PROMOTION_260219_260222  160324775010
#
#     Campaign start date Campaign end date Targeting strategy  \
# ...
